# %% [markdown]
# <h1 align='center' style='color:purple'> Speech Recognition 語音識別 - 課程 04-  Speech Recognition - Voice feature - DTW-MFCC - 語音特徵 - 動態時間扭曲-梅爾頻率倒譜係數 - Python Tutorial</h1>

# %% [raw]
# '''
#
# 人工智慧-深度學習
#
# A.I Tutorials
# Deep Learning 教程
#
# '''
#
#     04 - 課程    - Speech Recognition 語音識別
#
#          課程 04 - Speech Recognition
#                             - Voice feature - 語音特徵
#                                             - DTW  - Dynamic Time Warping
#                                             - MFCC - Mel Frequency Cepstral Coefficient
#
#
#          課程 04 - 語音識別  - 語音特徵 - Voice feature
#                                             -  DTW  - 動態時間扭曲
#                                             -  MFCC - 梅爾頻率倒譜係數
#
#                   程式範例 -  語音特徵 -DTW_MFCC - 動態時間扭曲_梅爾頻率倒譜係數
#
#
# '''  教程簡介 '''
# '''  語音識別 '''
#
# '''

# %% [raw]
# '''
#
# >> 資料準備
#
#     >> 你我互動學習園地
#         >> https://interactiveuandmetutorials.weebly.com/
#
#     >> Python 程式語言 設計
#        >> https://pythonprogrammingtutorials.weebly.com/
#
#
# >> 檔案路徑/
#     ├── 課程 04-  Speech Recognition - Voice feature - DTW_MFCC  - 語音識別 - 語音特徵 -DTW_MFCC - 動態時間扭曲/梅爾頻率倒譜係數
#     ├── sounds/
#     ├      ├── 10.wav
#     ├      ├── 78.wav
#     ├
#     ├
#     ├── dtw.py
#
#
#
# '''

# %%
ddir
# Out:
#  磁碟區 C 中的磁碟是 OS
#  磁碟區序號:  68E3-32FD
#
#  C:\Users\calvi\OneDrive\桌面\課程SpeechRecogination\課程4 的目錄
#
# 2019/09/24  下午 01:25    <DIR>          .
# 2019/09/24  下午 01:25    <DIR>          ..
# 2019/09/24  上午 11:53    <DIR>          .ipynb_checkpoints
# 2019/09/24  上午 11:50    <DIR>          sounds
#                0 個檔案               0 位元組
#                4 個目錄  44,782,665,728 位元組可用

# %%
cd sounds
# Out:
# C:\Users\calvi\OneDrive\桌面\課程SpeechRecogination\課程4\sounds

# %%
ls
# Out:
#  磁碟區 C 中的磁碟是 OS
#  磁碟區序號:  68E3-32FD
#
#  C:\Users\calvi\OneDrive\桌面\課程SpeechRecogination\課程4\sounds 的目錄
#
# 2019/09/24  上午 11:50    <DIR>          .
# 2019/09/24  上午 11:50    <DIR>          ..
# 2018/09/12  下午 11:09            93,228 10.wav
# 2018/09/12  下午 11:09            76,844 78.wav
#                2 個檔案         170,072 位元組
#                2 個目錄  44,779,900,928 位元組可用

# %%
cd ..
# Out:
# C:\Users\calvi\OneDrive\桌面\課程SpeechRecogination\課程4

# %%
ddir
# Out:
#  磁碟區 C 中的磁碟是 OS
#  磁碟區序號:  68E3-32FD
#
#  C:\Users\calvi\OneDrive\桌面\課程SpeechRecogination\課程4 的目錄
#
# 2019/09/24  下午 01:25    <DIR>          .
# 2019/09/24  下午 01:25    <DIR>          ..
# 2019/09/24  上午 11:53    <DIR>          .ipynb_checkpoints
# 2019/09/24  上午 11:50    <DIR>          sounds
#                0 個檔案               0 位元組
#                4 個目錄  44,777,050,112 位元組可用

# %% [raw]
# '''
#
# >>  語音識別
#     >> Speech Recognition
#
#
# '''

# %% [markdown]
# <img src="https://i1.wp.com/www.simplifiedpython.net/wp-content/uploads/2018/07/speech-recognition-python-1.png?w=682&ssl=1" width="100%">

# %% [raw]
# '''
#
# >> 語音識別 的方法 示意如圖所示
#     >> The approach used in this example for speaker identification is shown in the diagram
#
# '''

# %% [markdown]
# <img src="https://www.mathworks.com/help/examples/audio_wavelet/win64/xxSpeakerID01.png" width="100%">

# %% [markdown]
# <img src="https://devblogs.nvidia.com/wp-content/uploads/2019/03/pasted-image-0-19-768x287.png" width="100%">

# %% [markdown]
# <img src="https://miro.medium.com/max/2000/0*SukgVDWR-kBWrPqf." width="100%">

# %% [raw]
# '''
#
# >> 頻譜圖 - Spectrogram
#
#     >> 一個軸代表時間，另一個軸代表頻率
#
#
#     >> 音頻數據中 - 看到音符和其他音高模式
#         >>  musical notes and other pitch patterns in audio data
#
#     >> https://en.wikipedia.org/wiki/Spectrogram
# '''

# %% [markdown]
# <img src="https://miro.medium.com/max/2421/1*bhd7B-s-Qnds3HGV6LOo8A.png" width="100%">

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/5/58/Scaleogram.png" width="100%">

# %% [raw]
# '''
#
# >> 譜圖 - Spectrogram
# >> 格式有很多種：
#     >> 有時垂直 和 水平軸都會切換
#     >> 時間會上下移動
#         >> 有時作為 瀑布圖
#             >> 其中幅度由 3D表面的高度 而不是顏色或強度表示。
#             >> 頻率 和幅度軸 可以是 線性軸或 對數軸，具體取決於圖形的用途
#             >> 音頻 通常用 對數幅度軸（可能以 分貝或dB 表示）表示
#             >> 頻率 為線性
#                 >> 以強調 諧波關係，或 對數以強調 音樂， 音調關係
#
#
# '''

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/2/29/Spectrogram_of_violin.png" width="100%">

# %%
'''

>> 第三維 由圖像中每個點的 強度 或顏色表示
    >> 指示特定時 間的特定頻率的幅度

'''

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/0/04/Spectrogram.png" width="100%">

# %% [raw]
# '''
#
# >> 動態時間扭曲/調整
#     >> Dynamic Time Warping（DTW）
#
#     >> 一種衡量- 兩個時間序列之間的 - 相似度的方法
#         >> 主要應用在- 語音識別領域
#             >> 識別兩段語音是否表示 - 同一個單詞
#
# '''

# %% [raw]
# '''
#
# >> DTW- 方法原理
#
#     >> 時間序列中
#         >> 需要比較相似性的 兩段時間序列的長度可能並不相等
#             >> 語音識別領域表現為不同人的語速不同
#         >> 而且同一個單詞內的不同音素的發音 速度也不同
#             >> 比如有時會把
#                 >> " A " 這個音拖得很長
#                 >>  或者 " i " 發的很短
#         >> 另外
#             >> 不同時間序列 可能僅僅存在 時間軸上的位移
#             >> 亦即在 還原位移的情況下，兩個時間序列是一致的
#
#             >> 在這些複雜情況下
#                 >> 使用傳統的歐幾里得距離
#                 >> 無法有效地
#                     >> 求的兩個時間序列之間的距離 - 或者相似性
#
# '''

# %% [raw]
# '''
#
# >> DTW- 方法
#     >> DTW method works
#     >> DTW 通過把時間序列進行延伸 和 縮短
#         >> 來計算兩個時間序列性之間 的相似性
#
# '''

# %% [markdown]
# <img src="https://databricks.com/wp-content/uploads/2019/04/Euclidean_vs_DTW.jpg" width="50%">

# %% [raw]
# '''
#
# >>  DTW - 計算方法
#     >> 算相似度的兩個時間序列為X和Y，長度分別為|X|和|Y|
#     >> 矩陣(Cost Matrix)
#
# '''

# %% [markdown]
# <img src="https://www.frontiersin.org/files/Articles/185061/fncom-10-00046-HTML/image_m/fncom-10-00046-g001.jpg" width="100%">

# %%
'''

>>   DTW - x1 和 x2時間序列與DTW相比
    >>  DTW - x1 and x2 time series compared 

'''

# %% [markdown]
# <img src="https://www.frontiersin.org/files/Articles/241994/fnins-11-00075-HTML/image_m/fnins-11-00075-g001.jpg" width="100%">

# %% [raw]
# '''
#
# >> 語音特徵 Voice Feature
#     >> MFCC - Mel-scaleFrequency Cepstral Coefficients，簡稱MFCC
#     >> 語音識別（SpeechRecognition）和 話者識別（SpeakerRecognition）方面
#         >> 最常用到的 語音特徵
#             >> 梅爾倒譜系數（Mel-scaleFrequency Cepstral Coefficients，簡稱MFCC）
#
#
#     >> 根據人耳 聽覺機理的 研究發現
#         >> 人耳 對不同頻率的聲波有不同的 聽覺敏感度
#         >> 200Hz - 5000Hz的 語音訊號對語音
#             >> 清晰度 影響對大
#
#     >> 梅爾倒譜系數（Mel-scale Frequency Cepstral Coefficients，簡稱MFCC）
#         >> 是在 Mel標度頻率域 提取出來的 倒譜引數
#         >> Mel標度 描述了 人耳頻率的 - 非線性特性
#             >> 與頻率的關係可用下式近似表示
#
#
#         >> Mel標度頻率域提-取出來的倒譜引數
#             >> Mel標度描述了人耳頻率的非線性特性
#
#     >> 頻率的關係可用下式表示
#             >> Mel(f)=2395 x lg(1+f/700)
#
# '''

# %% [markdown]
# <img src="https://miro.medium.com/max/900/1*64Wucrt-BeUH9ZVyOHyi2A.jpeg" width="100%">

# %% [markdown]
# <img src="https://static.oschina.net/uploads/space/2014/0115/164237_zhTS_852488.jpg" width="100%">

# %% [raw]
# '''
#
# >> 提取 RAS-MFCC特徵 -方塊圖
#     >> extracting RAS-MFCC features Blocks
#
#     >> 濾波器組指的是mel濾波器（轉換為mel音階）
#         >>
#     >> 倒譜係數只是MFCC
#         >> Cepstral Coefficients are nothing but MFCCs
#
# '''

# %% [markdown]
# <img src="https://miro.medium.com/max/1071/1*dWnjn5LLS0j8St53ACwqSg.jpeg" width="100%">

# %% [raw]
# '''
#
# >> 語音識別系統的階段
#     >> Stages of Speech Recognition System
#
# '''

# %% [markdown]
# <img src="https://d3i71xaburhd42.cloudfront.net/c0fd455b8ea61d00a1cc3e6eaddae9502c9cdf05/1-Figure1-1.png" width="100%">

# %% [raw]
# '''
#
# >> 語音信號中提取的特徵
#     >> Features extracted from speech signals
#
#     >> Fourier transform - 傅里葉變換
#
# '''

# %% [markdown]
# <img src="https://miro.medium.com/max/1000/1*rT54GmJmFG0PU9OQHzQUVg.png" width="100%">

# %% [raw]
# '''
#
# >> Cepstrum was first introduced to characterize
#     >> 倒譜 首次被引入以表徵
#
# '''

# %% [markdown]
# <img src="https://miro.medium.com/max/903/1*pmjqw39CpC9FHb7o4CmKOA.png" width="100%">

# %% [raw]
# '''
#
# >> MFCC Coefficienrts - 係數
#
#     >> 從 語音信號 中提取的- 特徵
#         >> Features extracted from speech signals
#
# '''

# %% [markdown]
# <img src="https://miro.medium.com/max/2144/1*pzE4i1TXaLCmzTXgdxFZjQ.jpeg" width="100%">

# %% [markdown]
# # 程式範例

# %%
ddir
# Out:
#  磁碟區 C 中的磁碟是 OS
#  磁碟區序號:  68E3-32FD
#
#  C:\Users\calvi\OneDrive\桌面\課程SpeechRecogination\課程4 的目錄
#
# 2019/09/24  下午 01:57    <DIR>          .
# 2019/09/24  下午 01:57    <DIR>          ..
# 2019/09/24  上午 11:53    <DIR>          .ipynb_checkpoints
# 2019/09/24  上午 11:50    <DIR>          sounds
#                0 個檔案               0 位元組
#                4 個目錄  43,320,442,880 位元組可用

# %%
cd ..
# Out:
# C:\Users\calvi\OneDrive\桌面\課程SpeechRecogination

# %%
cd sounds
# Out:
# C:\Users\calvi\OneDrive\桌面\課程SpeechRecogination\sounds

# %%
ls
# Out:
#  磁碟區 C 中的磁碟是 OS
#  磁碟區序號:  68E3-32FD
#
#  C:\Users\calvi\OneDrive\桌面\課程SpeechRecogination\sounds 的目錄
#
# 2019/09/18  下午 03:29    <DIR>          .
# 2019/09/18  下午 03:29    <DIR>          ..
# 2018/09/12  下午 11:09            93,228 10.wav
# 2018/09/12  下午 11:09            76,844 78.wav
#                2 個檔案         170,072 位元組
#                2 個目錄  47,465,324,544 位元組可用

# %%
cd ..
# Out:
# C:\Users\calvi\OneDrive\桌面\課程SpeechRecogination

# %%
ls
# Out:
#  磁碟區 C 中的磁碟是 OS
#  磁碟區序號:  68E3-32FD
#
#  C:\Users\calvi\OneDrive\桌面\課程SpeechRecogination\sounds 的目錄
#
# 2019/09/18  下午 03:29    <DIR>          .
# 2019/09/18  下午 03:29    <DIR>          ..
# 2018/09/12  下午 11:09            93,228 10.wav
# 2018/09/12  下午 11:09            76,844 78.wav
#                2 個檔案         170,072 位元組
#                2 個目錄  43,241,848,832 位元組可用

# %%
cd ..
# Out:
# C:\Users\calvi\OneDrive\桌面\課程SpeechRecogination

# %% [markdown]
# # 程式範例

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import numpy 
print(numpy.__version__)
# Out:
# 1.14.2

# %%
import dtw
from dtw import dtw

# %%
x = array([0, 0, 1, 1, 2, 4, 2, 1, 2, 0]).reshape(-1, 1)
y = array([1, 1, 1, 2, 2, 2, 2, 3, 2, 0]).reshape(-1, 1)

# %%
plot(x)
plot(y)

# %% [raw]
# '''
#
# >> 計算 -DTW
#     >> Compute -DTW
#     >> Dynamic Time Warping（DTW）
#         >> 是一種衡量 兩個時間序列 之間的 相似度的方法
#     >> 主要應用在
#         >> 語音識別領域來識別兩段語音
#         >> 是否表示同一個單詞
#
# '''

# %%
dist, cost, acc, path = dtw(x, y, dist=lambda x, y: norm(x - y, ord=1))

# %%
print('Minimum distance found:', dist)
# Out:
# Minimum distance found: 0.2

# %% [raw]
#  '''
#
# >> 繪製累積成本矩陣 - " cost matrix " 和 " 最短 "路徑。。
#     >> plot the accumulated cost matrix and the "shortest" wrap path.
#
#     >> dtw.py
#
# '''

# %%
imshow(acc.T, origin='lower', cmap=cm.gray, interpolation='nearest')
plot(path[0], path[1], 'w')
xlim((-0.5, acc.shape[0]-0.5))
ylim((-0.5, acc.shape[1]-0.5))
# Out:
# (-0.5, 9.5)

# %% [markdown]
# # 程式範例

# %%
def my_custom_norm(x, y):
    return (x * x) + (y * y)

dist, cost, acc, path = dtw(x, y, dist=my_custom_norm)

# %%
from numpy.linalg import norm

dist, cost, acc, path = dtw(x, y, dist=norm)
# Out:
# C:\Users\calvi\Anaconda36\lib\site-packages\numpy\linalg\linalg.py:2249: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   (ord in ('f', 'fro') and ndim == 2) or

# %%
x = [1, 2, 3, 4, 5, 6, 7, 8, 9, 0]
y = [0] * 5 + x

x = array(x).reshape(-1, 1)
y = array(y).reshape(-1, 1)

# %%
imshow(acc.T, origin='lower', cmap=cm.gray, interpolation='nearest')
plot(path[0], path[1], 'w')
xlim((-0.5, acc.shape[0]-0.5))
ylim((-0.5, acc.shape[1]-0.5))
# Out:
# (-0.5, 9.5)

# %% [raw]
# '''
#
# >> 計算 MFCC - 兩個聲音
#     >> Compute the MFCCs of two sounds
#
#     >> sounds/10.wav
#     >> sounds/78.wav
#
# '''

# %% [raw]
# '''
#
# >> 計算 -DTW
#     >> Compute -DTW
#     >> Dynamic Time Warping（DTW）
#         >> 是一種衡量兩個時間序列之間的相似度的方法
#     >> 主要應用在語音識別領域來識別兩段語音
#         >> 是否表示同一個單詞
#
#
#     >> https://librosa.github.io/librosa/
#         >> pip install librosa
#
# '''

# %%
import IPython.display as ipd

# %%
import librosa
y1, sr1 = librosa.load('audio_files\jackhammer.wav')
ipd.Audio(y1, rate=sr1)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import librosa

y1, sr1 = librosa.load('./sounds/10.wav')
y2, sr2 = librosa.load('./sounds/78.wav')

# %%
x, sr = librosa.load('./sounds/10.wav')
ipd.Audio(x, rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import matplotlib.pyplot as plt
import librosa.display 
# %matplotlib inline

plt.subplot(1, 2, 1)
mfcc1 = librosa.feature.mfcc(y1, sr1)
librosa.display.specshow(mfcc1)

# %%
plt.figure(figsize=(15, 5))
librosa.display.waveplot(x, sr, alpha=0.8)

# %%
x, sr = librosa.load('./sounds/78.wav')
ipd.Audio(x, rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.figure(figsize=(15, 5))
librosa.display.waveplot(x, sr, alpha=0.8)

# %%
import matplotlib.pyplot as plt
import librosa.display 
# %matplotlib inline

plt.subplot(1, 2, 2)
mfcc2 = librosa.feature.mfcc(y2, sr2)
librosa.display.specshow(mfcc2)

# %% [raw]
# '''
#
# >> librosa.feature.mfcc
#     >> https://librosa.github.io/librosa/generated/librosa.feature.mfcc.html
#
# '''

# %%
import matplotlib.pyplot as plt
import librosa.display 
# %matplotlib inline

plt.subplot(1, 2, 1)
mfcc1 = librosa.feature.mfcc(y1, sr1)
librosa.display.specshow(mfcc1)

plt.subplot(1, 2, 2)
mfcc2 = librosa.feature.mfcc(y2, sr2)
librosa.display.specshow(mfcc2)

# %%
# Number of MFCCs: 20 (Librosa default)
print(mfcc1.shape)
print(mfcc2.shape)
# Out:
# (20, 46)
# (20, 38)

# %%
''

>> Compare them using DTW

    >> numpy.linalg.norm
    >> from numpy.linalg import norm 
        >> https://docs.scipy.org/doc/numpy/reference/generated/numpy.linalg.norm.html

'''

# %%
from dtw import dtw
from numpy.linalg import norm

dist, cost, acc_cost, path = dtw(mfcc1.T, mfcc2.T, dist=lambda x, y: norm(x - y, ord=1))
print('Normalized distance between the two sounds:', dist)
# Out:
# Normalized distance between the two sounds: 192.48170790356028

# %%
cost.shape
# Out:
# (46, 38)

# %%
plt.imshow(cost.T, origin='lower', cmap=plt.cm.gray, interpolation='nearest')
plt.plot(path[0], path[1], 'w')
plt.xlim((-0.5, cost.shape[0]-0.5))
plt.ylim((-0.5, cost.shape[1]-0.5))
# Out:
# (-0.5, 37.5)
